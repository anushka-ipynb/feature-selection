# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('housingprice.csv')

# %%
df.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %% [markdown]
# #### main aim is to find the sales price. we're only using the numerical features in this case, because we'll have to handle categorical features, which we don't have to for this explanation.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
house_df = df.select_dtypes(include=np.number)

# %%
house_df.drop(['Id'],axis=1,inplace=True)

# %%
X = house_df.drop(['SalePrice'],axis=1)
y = house_df['SalePrice']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=0,test_size=0.3)

# %%
X_train.isnull().sum()
# Out:
# MSSubClass         0
# LotFrontage      189
# LotArea            0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# MasVnrArea         5
# BsmtFinSF1         0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       0
# BsmtHalfBath       0
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# Fireplaces         0
# GarageYrBlt       54
# GarageCars         0
# GarageArea         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# dtype: int64

# %%
from sklearn.feature_selection import mutual_info_regression
mutual_info = mutual_info_regression(X_train.fillna(0),y_train)

# %%
mutual_info = pd.Series(mutual_info)
mutual_info.index = X_train.columns

# %%
mutual_info.sort_values(ascending=False)
# Out:
# OverallQual      0.528617
# GrLivArea        0.481403
# TotalBsmtSF      0.386388
# GarageCars       0.379937
# GarageArea       0.369880
# YearBuilt        0.350837
# 1stFlrSF         0.309967
# FullBath         0.273392
# GarageYrBlt      0.272261
# MSSubClass       0.254962
# YearRemodAdd     0.237954
# 2ndFlrSF         0.223133
# LotFrontage      0.209794
# TotRmsAbvGrd     0.177042
# OpenPorchSF      0.176208
# Fireplaces       0.171250
# LotArea          0.165061
# BsmtFinSF1       0.157570
# BsmtUnfSF        0.112652
# MasVnrArea       0.101431
# OverallCond      0.101085
# HalfBath         0.091327
# WoodDeckSF       0.072501
# BedroomAbvGr     0.031848
# KitchenAbvGr     0.023676
# BsmtFullBath     0.020792
# ScreenPorch      0.017075
# 3SsnPorch        0.008192
# EnclosedPorch    0.005412
# LowQualFinSF     0.002604
# BsmtFinSF2       0.002381
# PoolArea         0.001333
# BsmtHalfBath     0.000000
# MiscVal          0.000000
# MoSold           0.000000
# ...

# %%
from sklearn.feature_selection import SelectPercentile

# %%
selected_top_columns = SelectPercentile(mutual_info_regression, percentile=20)
selected_top_columns.fit(X_train.fillna(0), y_train)
X_train.columns[selected_top_columns.get_support()]
# Out:
# Index(['OverallQual', 'YearBuilt', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea',
#        'GarageCars', 'GarageArea'],
#       dtype='object')

# %% [markdown]
# ### these are the columns that belong to the top 20th percentile
